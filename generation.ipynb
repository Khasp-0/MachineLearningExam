# %% [markdown]
# # To Do
# Generate plots, kinematics for every variable (10) Energies, momentums, angles, masses

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# 1 refers to Proton, 2 refers to Pion 
def decay_generator(M, m_1, m_2):
    E_1 = (M^2 + m_1^2 - m_2^2)/(2*M)
    E_2 = (M^2 + m_2^2 - m_1^2)/(2*M)
    p_1 = np.sqrt(E_1^2 - m_1^2)
    p_1 = np.sqrt(E_2^2 - m_2^2)
